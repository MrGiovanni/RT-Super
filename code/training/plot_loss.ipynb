# %%
import losses_foundation as l
import importlib
importlib.reload(l)
# Out:
# <module 'losses_foundation' from '/Users/pedrobassi/Documents/GitHub/R-Super/foundational/MedFormer/training/losses_foundation.py'>

# %%
l.plot_volume_loss_curve(-1000, (1000,10000000,10))
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  (<Axes: title={'center': 'Volume loss vs. prediction (target=-1000, tol=0.1)'}, xlabel='Predicted volume (mm³)', ylabel='Loss'>,
#   <Axes: xlabel='Predicted volume (mm³)', ylabel='d(Loss)/d(Vol)'>),
#  array([1.00000e+03, 1.01000e+03, 1.02000e+03, ..., 9.99998e+06,
#         9.99999e+06, 1.00000e+07], dtype=float32),
#  array([0.       , 0.       , 0.       , ..., 0.8339825, 0.8339827,
#         0.8339828], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.4901161e-08,
#         1.4901161e-08, 1.1920929e-08], dtype=float32))
